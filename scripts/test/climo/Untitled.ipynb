# %%
import subprocess

def salloc(nodes=1, ntasks=2, time="00:10:00"):
    cmd = f"salloc --nodes={nodes} --ntasks-per-node={ntasks} --time={time}"
    process = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(f"SLURM job requested. Process ID: {process.pid}")
    return process

# Example call
salloc()

# %%
# !squeue -u $USER

# %%
# Scale up to use multiple workers
cluster.scale(jobs=2)  # Adjust as needed

# Create a Dask client
client = Client(cluster)

# # Print client and cluster status
# print(client)
print(cluster.dashboard_link)
